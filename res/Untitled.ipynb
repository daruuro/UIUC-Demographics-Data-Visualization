# %%
import pandas as pd
df = pd.read_csv("Final Data Set.csv")
df = df.fillna(0)
df["International"] = df["Total"] - (df["Caucasian"] + df["Asian American"] + df["African American"] + df["Hispanic"] + df["Native American"] + df["Unknown"])
df = df.drop("Unnamed: 0", axis=1)
df
# Out:
#      Term/Year Code College                       Major Name   Total     Men  \
# 0              2005     KM                      Accountancy   1261.0   687.0
# 1              2010     KM                      Accountancy   1273.0   672.0
# 2              2015     KM                      Accountancy   1422.0   687.0
# 3              2005     KV                Actuarial Science    249.0   167.0
# 4              2010     KV                Actuarial Science    292.0   169.0
# 5              2015     KV                Actuarial Science    389.0   224.0
# 6              2005     KT                      Advertising    263.0    67.0
# 7              2010     KT                      Advertising    526.0   158.0
# 8              2015     KT                      Advertising    589.0   186.0
# 9              2005     KP         Aero & Astro Engineering     48.0    42.0
# 10             2005     KP            Aerospace Engineering    381.0   326.0
# ...

# %%
df.to_csv("Final Data Set.csv")
